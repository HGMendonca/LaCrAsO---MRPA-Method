# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})
plt.rcParams.update({'text.usetex': True})
plt.rcParams.update({'text.latex.preamble' : r'\usepackage{amsmath}'})

# %%
data = np.loadtxt('susn435g512a02-c1.dat')
d1 = data[:,0]
charge1 = data[:,1]+1j*data[:,2]
spin1 = data[:,3]+1j*data[:,4]

data = np.loadtxt('susn435g512a02-c2.dat')
d2 = data[:,0]
charge2 = data[:,1]+1j*data[:,2]
spin2 = data[:,3]+1j*data[:,4]

data = np.loadtxt('susn435g512a02-c3.dat')
d3 = data[:,0]
charge3 = data[:,1]+1j*data[:,2]
spin3= data[:,3]+1j*data[:,4]

data = np.loadtxt('susn435g512a02-c4.dat')
d4 = data[:,0]
charge4 = data[:,1]+1j*data[:,2]
spin4 = data[:,3]+1j*data[:,4]

data = np.loadtxt('susn435g512a02-c5.dat')
d5 = data[:,0]
charge5 = data[:,1]+1j*data[:,2]
spin5 = data[:,3]+1j*data[:,4]

data = np.loadtxt('susn435g512a02-c6.dat')
d6 = data[:,0]
charge6 = data[:,1]+1j*data[:,2]
spin6= data[:,3]+1j*data[:,4]

data = np.loadtxt('susn435g512a02-c7.dat')
d7 = data[:,0]
charge7 = data[:,1]+1j*data[:,2]
spin7 = data[:,3]+1j*data[:,4]

data = np.loadtxt('susn435g512a02-c8.dat')
d8 = data[:,0]
charge8 = data[:,1]+1j*data[:,2]
spin8 = data[:,3]+1j*data[:,4]

data = np.loadtxt('susn435g512a02-c9.dat')
d9 = data[:,0]
charge9 = data[:,1]+1j*data[:,2]
spin9 = data[:,3]+1j*data[:,4]

data = np.loadtxt('susn435g512a02-c10.dat')
d10 = data[:,0]
charge10 = data[:,1]+1j*data[:,2]
spin10 = data[:,3]+1j*data[:,4]

data = np.loadtxt('susn435g512a02-c11.dat')
d11 = data[:,0]
charge11 = data[:,1]+1j*data[:,2]
spin11 = data[:,3]+1j*data[:,4]

# %%
data = np.loadtxt('uvaln435g512-c.dat')
U = data[:,1]
J = data[:,2]

print(U)
print(J)
# Out:
# [0.51 0.52 0.53 0.54 0.55 0.56 0.57 0.58 0.59 0.6  0.61]
# [0.1275 0.13   0.1325 0.135  0.1375 0.14   0.1425 0.145  0.1475 0.15
#  0.1525]

# %%
plt.plot(d1, np.real(spin1), c='orange', ls='solid', label=r'$U=$'+str(round(float(U[0]), 2))+',$J=$'+str(round(float(J[0]),3)))
plt.plot(d2, np.real(spin2), c='lime', ls='solid', label=r'$U=$'+str(round(float(U[1]), 2))+',$J=$'+str(round(float(J[1]),3)))
plt.plot(d3, np.real(spin3), c='magenta', ls='solid', label=r'$U=$'+str(round(float(U[2]), 2))+',$J=$'+str(round(float(J[2]),3)))
plt.plot(d4, np.real(spin4), c='yellow', ls='solid', label=r'$U=$'+str(round(float(U[3]), 2))+',$J=$'+str(round(float(J[3]),3)))
plt.plot(d5, np.real(spin5), c='grey', ls='solid', label=r'$U=$'+str(round(float(U[4]), 2))+',$J=$'+str(round(float(J[4]),3)))
plt.plot(d6, np.real(spin6), c='blue', ls='solid', label=r'$U=$'+str(round(float(U[5]), 2))+',$J=$'+str(round(float(J[5]),3)))
plt.plot(d7, np.real(spin7), c='green', ls='solid', label=r'$U=$'+str(round(float(U[6]), 2))+',$J=$'+str(round(float(J[6]),3)))
plt.plot(d8, np.real(spin8), c='deepskyblue', ls='solid', label=r'$U=$'+str(round(float(U[7]), 2))+',$J=$'+str(round(float(J[7]),3)))
plt.plot(d9, np.real(spin9), c='purple', ls='solid', label=r'$U=$'+str(round(float(U[8]), 2))+',$J=$'+str(round(float(J[8]),3)))
#plt.plot(d10, np.real(spin10), c='red', ls='solid', label=r'$U=$'+str(round(float(U[9]), 2))+',$J=$'+str(round(float(J[9]),3)))
#plt.plot(d11, np.real(spin11), c='black', ls='solid', label=r'$U=$'+str(round(float(U[10]), 2))+',$J=$'+str(round(float(J[10]),3)))
#plt.ylim(-1, 8)
plt.title(r'$n=3.5, NGRID=512$')
plt.legend(bbox_to_anchor=(1.01, 1))
plt.ylabel(r'$\chi_S$')
plt.xticks([0, np.pi, 2*np.pi, 3*np.pi], [r'$\Gamma$', r'$X$', r'$M$', r'$\Gamma$'])
plt.grid()
plt.savefig('x_S.pdf', bbox_inches='tight')

plt.show()

# %%
plt.plot(d1, np.real(charge1), c='orange', ls='solid', label=r'$U=$'+str(round(float(U[0]), 2))+',$J=$'+str(round(float(J[0]),3)))
plt.plot(d2, np.real(charge2), c='lime', ls='solid', label=r'$U=$'+str(round(float(U[1]), 2))+',$J=$'+str(round(float(J[1]),3)))
plt.plot(d3, np.real(charge3), c='magenta', ls='solid', label=r'$U=$'+str(round(float(U[2]), 2))+',$J=$'+str(round(float(J[2]),3)))
plt.plot(d4, np.real(charge4), c='yellow', ls='solid', label=r'$U=$'+str(round(float(U[3]), 2))+',$J=$'+str(round(float(J[3]),3)))
plt.plot(d5, np.real(charge5), c='grey', ls='solid', label=r'$U=$'+str(round(float(U[4]), 2))+',$J=$'+str(round(float(J[4]),3)))
plt.plot(d6, np.real(charge6), c='blue', ls='solid', label=r'$U=$'+str(round(float(U[5]), 2))+',$J=$'+str(round(float(J[5]),3)))
plt.plot(d7, np.real(charge7), c='green', ls='solid', label=r'$U=$'+str(round(float(U[6]), 2))+',$J=$'+str(round(float(J[6]),3)))
plt.plot(d8, np.real(charge8), c='deepskyblue', ls='solid', label=r'$U=$'+str(round(float(U[7]), 2))+',$J=$'+str(round(float(J[7]),3)))
plt.plot(d9, np.real(charge9), c='purple', ls='solid', label=r'$U=$'+str(round(float(U[8]), 2))+',$J=$'+str(round(float(J[8]),3)))
plt.plot(d10, np.real(charge10), c='red', ls='solid', label=r'$U=$'+str(round(float(U[9]), 2))+',$J=$'+str(round(float(J[9]),3)))
plt.plot(d11, np.real(charge11), c='black', ls='solid', label=r'$U=$'+str(round(float(U[10]), 2))+',$J=$'+str(round(float(J[10]),3)))
plt.ylim(0, 2)
plt.title(r'$n=3.5, NGRID=512$')
plt.legend(bbox_to_anchor=(1.01, 1))
plt.ylabel(r'$\chi_C$')
plt.xticks([0, np.pi, 2*np.pi, 3*np.pi], [r'$\Gamma$', r'$X$', r'$M$', r'$\Gamma$'])
plt.grid()
plt.savefig('x_C.pdf', bbox_inches='tight')

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------
